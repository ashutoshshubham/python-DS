# %%
#pip install seaborn plotly matplotlib

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_excel('Canada.xlsx', skiprows = 20,skipfooter = 2, sheet_name = 'Canada by Citizenship')

# %%
cols_to_drop = ['Type','Coverage','AREA','REG','DEV']
df.drop(columns = cols_to_drop,inplace = True)
years = range(1980,2014)
df.rename({'OdName':'Country','AreaName':'Continent','RegName':'Region','DevName':'Status'}, axis = 1,inplace = True)
df.set_index('Country', inplace = True)
df['Total'] = df[years].sum(axis = 1)
df.head(3)
# Out:
#             Continent           Region              Status  1980  1981  1982  \
# Country
# Afghanistan      Asia    Southern Asia  Developing regions    16    39    39
# Albania        Europe  Southern Europe   Developed regions     1     0     0
# Algeria        Africa  Northern Africa  Developing regions    80    67    71
#
#              1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  \
# Country
# Afghanistan    47    71   340   496   741   828  1076  1028  1378  1170   713
# Albania         0     0     0     1     2     2     3     3    21    56    96
# Algeria        69    63    44    69   132   242   434   491   872   795   717
#
#              1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  \
# Country
# Afghanistan   858  1537  2212  2555  1999  2395  3326  4067  3697  3479  2978
# Albania        71    63   113   307   574  1264  1816  1602  1021   853  1450
# Algeria       595  1106  2054  1842  2292  2389  2867  3418  3406  3072  3616
# ...

# %%
df.sort_values(by = 'Total',inplace = True,ascending = False)
df.head(10)
# Out:
#                                                            Continent  \
# Country
# India                                                           Asia
# China                                                           Asia
# United Kingdom of Great Britain and Northern Ir...            Europe
# Philippines                                                     Asia
# Pakistan                                                        Asia
# United States of America                            Northern America
# Iran (Islamic Republic of)                                      Asia
# Sri Lanka                                                       Asia
# Republic of Korea                                               Asia
# Poland                                                        Europe
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# ...

# %%
df.head(10)['Total'].plot(kind = 'bar',figsize = (15,5),title = 'Top 10 countries')
# Out:
# <AxesSubplot: title={'center': 'Top 10 countries'}, xlabel='Country'>

# %%
df.head(25)['Total'].plot(kind = 'bar',figsize = (15,5),title = 'Top 10 countries',color = 'hotpink', alpha = 0.5, edgecolor = 'white',hatch = '/',rot = 45)
plt.savefig('top 25 countries with immigration.jpg',bbox_inches = 'tight')

# %%
#compare India , china , UK
countries = ['India','China','France']
df.loc[countries,years].T.plot(kind = 'line',figsize=(15,6), style = ['ro-','g*--','bx--'],alpha = 0.5)
# Out:
# <AxesSubplot: >

# %%
# df.plot?

# %%
px.funnel(df.head(),x=df.head().index,y=[1980,1990,2000,2010])

# %% [markdown]
# line plots

# %%
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.loc['Japan', years].plot(linewidth = 2, color = 'red',linestyle = '-.',marker = '*',markersize = 10,
figsize = (20,7),xlabel = 'Years', ylabel = 'No. of People',fontsize = 20,title = 'Immigration Trends of Japan to Canada (1980-2013)',grid = False)
# Out:
# <AxesSubplot: title={'center': 'Immigration Trends of Japan to Canada (1980-2013)'}, xlabel='Years', ylabel='No. of People'>

# %%
df.loc['France', years].plot(linewidth = 2, color = 'red',linestyle = '-.',marker = '*',markersize = 10,
figsize = (20,7),xlabel = 'Years', ylabel = 'No. of People',fontsize = 20,title = 'Immigration Trends of France to Canada (1980-2013)',grid = False)
# Out:
# <AxesSubplot: title={'center': 'Immigration Trends of France to Canada (1980-2013)'}, xlabel='Years', ylabel='No. of People'>

# %% [markdown]
# area plot

# %%
df.loc['Republic of Korea', years].plot(kind = 'area',alpha = 0.6,color = 'green',table = False)
# Out:
# <AxesSubplot: >

# %%
countries = ['Republic of Korea', 'Japan']
colors = ['red','blue']
df.loc[countries, years].T.plot(kind = 'area',alpha = 0.4,color = colors)
# Out:
# <AxesSubplot: >

# %%
df.loc[countries, years].T.plot(kind = 'area',alpha = 0.4,color = colors,stacked = False,subplots = True,figsize = (20,5), layout = (1,2))
# Out:
# array([[<AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %% [markdown]
# pie chart

# %%
# colors = ['red','green','blue','yellow']
df['Total'].head(10).plot(kind = 'pie',radius = 2,autopct = '%.1f%%',wedgeprops = {'width':.5},textprops = {'color':'#333'})
# Out:
# <AxesSubplot: ylabel='Total'>

# %% [markdown]
# filter

# %%
df[df['Continent'] == 'Africa']['Total'].head(10).plot(kind = 'pie',radius = 2,autopct = '%.1f%%',wedgeprops = {'width':.5},textprops = {'color':'#333'})
# Out:
# <AxesSubplot: ylabel='Total'>

# %% [markdown]
# #### top ten countries with immigration with status == 'devloped'

# %%
a = df[df['Status'] == 'Developed regions']
b = a.head(10)
b['Total'].plot(kind = 'pie',radius = 1.2,autopct = '%.1f%%',wedgeprops = {'width':.5},textprops = {'color':'#333'})
# Out:
# <AxesSubplot: ylabel='Total'>

# %% [markdown]
# groupby

# %%
cdf = df.groupby(by = 'Continent')[list(years)].sum()
cdf
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
# Oceania                           1942   1839   1675   1018    878    920
#
#                                   1986   1987   1988   1989   1990   1991  \
# Continent
# Africa                            3782   7494   7552   9894  11012  14228
# Asia                             28739  43203  47454  60256  72829  89964
# Europe                           24370  46698  54726  60893  68301  57938
# Latin America and the Caribbean  21179  28471  21924  25060  27942  36827
# ...

# %%
cdf = df.groupby(by = 'Continent')[list(years)].agg([max,min])
cdf
# Out:
#                                   1980       1981       1982       1983      \
#                                    max min    max min    max min    max min
# Continent
# Africa                            1026   0   1118   0    781   0    474   0
# Asia                              8880   0   8670   0   8147   0   7338   0
# Europe                           22045   0  24796   0  20620   0  10015   0
# Latin America and the Caribbean   3198   0   3692   0   3575   0   2860   0
# Northern America                  9378   0  10030   0   9074   0   7100   0
# Oceania                            702   0    705   0    814   0    554   0
#
#                                   1984      1985      1986       1987      \
#                                    max min   max min   max min    max min
# Continent
# Africa                             473   0   460   0   718   0   1470   0
# Asia                              7583   0  5907   0  7150   0  10189   0
# ...

# %%
cdf = df.groupby(by = 'Continent')[list(years)].agg(['median','mean'])
cdf
# Out:
#                                    1980                 1981               \
#                                  median         mean  median         mean
# Continent
# Africa                              5.0    73.166667     4.5    80.796296
# Asia                               12.0   633.163265     6.0   700.285714
# Europe                             17.0   924.651163    20.0  1041.906977
# Latin America and the Caribbean   114.0   396.393939   117.0   461.060606
# Northern America                 4689.0  4689.000000  5015.0  5015.000000
# Oceania                             0.0   138.714286     1.0   131.357143
#
#                                    1982                 1983               \
#                                  median         mean  median         mean
# Continent
# Africa                              6.0    70.722222     3.5    49.462963
# Asia                               16.0   616.612245    16.0   504.000000
# ...

# %% [markdown]
# ## Histogram

# %%
cdf.loc['Africa',years].plot(kind='hist',bins = 5)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
cdf.loc['Asia',years].plot(kind='hist',bins = 5)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
cdf.loc['Asia',years].plot(kind='kde')
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# ## box plot

# %%
cdf.loc['Africa',years].plot(kind = 'box')
# Out:
# <AxesSubplot: >

# %%
cdf[years].T.plot(kind = 'box',figsize = (20,10))
# Out:
# <AxesSubplot: >
